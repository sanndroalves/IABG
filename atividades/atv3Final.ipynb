# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.DataFrame({
  'precisão na Montagem':np.array(['Alta','Média','Alta','Média','Baixa','Baixa']),
   'Velocidade de Produção':np.array(['Média','Baixa','Alta','Alta','Baixa','Média']),
   'Taxa de Retrabalho':np.array(['Baixa','Alta','Baixa','Baixa','Alta','Alta']), 
 'Classificação':np.array(['Alta Qualidade','Baixa Qualidade','Alta Qualidade','Alta Qualidade','Baixa Qualidade','Baixa Qualiadade']),
})

# %%
prec =np.array(['Alta','Média','Alta','Média','Baixa','Baixa'])
classificacao = np.array(['Alta Qualidade','Baixa Qualidade','Alta Qualidade','Alta Qualidade','Baixa Qualidade','Baixa Qualidade'])

# %%
dados.head(6)
# Out:
#   precisão na Montagem Velocidade de Produção Taxa de Retrabalho  \
# 0                 Alta                  Média              Baixa
# 1                Média                  Baixa               Alta
# 2                 Alta                   Alta              Baixa
# 3                Média                   Alta              Baixa
# 4                Baixa                  Baixa               Alta
# 5                Baixa                  Média               Alta
#
#       Classificação
# 0    Alta Qualidade
# 1   Baixa Qualidade
# 2    Alta Qualidade
# 3    Alta Qualidade
# 4   Baixa Qualidade
# 5  Baixa Qualiadade

# %%
prec = np.array([2,1,2,1,0,0])
classificacao = np.array(['Alta ','Baixa ','Alta ','Alta ','Baixa ','Baixa '])

# %%
precisao_treino, precisao_teste, classificacao_treino, classificacao_teste = train_test_split(prec.reshape(-1,1),classificacao.reshape(-1,1),test_size=0.3,random_state=42)

# %%
modelo = DecisionTreeClassifier()
modelo.fit(precisao_treino,classificacao_treino)
# Out:
# DecisionTreeClassifier()

# %%
previsoes = modelo.predict(precisao_teste)

# %%
print(previsoes)
# Out:
# ['Alta ' 'Alta ']

# %%
fig = plt.figure(figsize=(10,8))
tree.plot_tree(modelo,feature_names= prec.tolist(), class_names = classificacao.tolist(), filled= True)
# Out:
# [Text(0.5, 0.75, '2 <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Alta '),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Baixa '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Alta ')]
